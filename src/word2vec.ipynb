# %%
# !pip install gensim
# Out:
# Looking in indexes: http://repo.myhuaweicloud.com/repository/pypi/simple
# ...
#      |████████████████████████████████| 24.0 MB 12.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 58 kB 57.1 MB/s eta 0:00:01
# ...

# %%
import moxing as mox
mox.file.copy_parallel(src_url="s3://data96/word_embedding/corpus.txt", 
dst_url='corpus.txt')

# %%
from multiprocessing import cpu_count
from gensim.models import Word2Vec
from gensim.models import KeyedVectors
corpus_file = "corpus.txt"
out_embedding_file = "embedding.txt"

# %%
# ?Word2Vec
# Out:
# Init signature:
# Word2Vec(
#     sentences=None,
#     corpus_file=None,
#     vector_size=100,
#     alpha=0.025,
#     window=5,
#     min_count=5,
#     max_vocab_size=None,
#     sample=0.001,
#     seed=1,
#     workers=3,
#     min_alpha=0.0001,
#     sg=0,
#     hs=0,
#     negative=5,
#     ns_exponent=0.75,
#     cbow_mean=1,
#     hashfxn=<built-in function hash>,
#     epochs=5,
#     null_word=0,
#     trim_rule=None,
#     sorted_vocab=1,
#     batch_words=10000,
#     compute_loss=False,
#     callbacks=(),
#     comment=None,
#     max_final_vocab=None,
#     shrink_windows=True,
# )
# Docstring:
# Serialize/deserialize objects from disk, by equipping them with the `save()` / `load()` methods.
#
# Warnings
# --------
# This uses pickle internally (among other techniques), so objects must not contain unpicklable attributes
# such as lambda functions etc.
# Init docstring:
# Train, use and evaluate neural networks described in https://code.google.com/p/word2vec/.
#
# ...

# %%
model = Word2Vec(corpus_file=corpus_file, vector_size=100, window=5, min_count=5, 
workers=cpu_count(), sg=1)
model.wv.save_word2vec_format(out_embedding_file, binary=False)
# Out:
# INFO:gensim.models.word2vec:collecting all words and their counts
# INFO:gensim.models.word2vec:PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# INFO:gensim.models.word2vec:collected 434258 word types from a corpus of 8163235 raw words and 6566 sentences
# INFO:gensim.models.word2vec:Creating a fresh vocabulary
# INFO:gensim.utils:Word2Vec lifecycle event {'msg': 'effective_min_count=5 retains 99249 unique words (22.854846657977514%% of original 434258, drops 335009)', 'datetime': '2022-03-28T04:10:24.836724', 'gensim': '4.1.2', 'python': '3.7.6 | packaged by conda-forge | (default, Jun  1 2020, 18:15:32) \n[GCC 7.5.0]', 'platform': 'Linux-4.19.36-vhulk1907.1.0.h619.eulerosv2r8.aarch64-aarch64-with-centos-2.0-SP8', 'event': 'prepare_vocab'}
# ...

# %%
word2vec_model = KeyedVectors.load_word2vec_format("embedding.txt")
# Out:
# INFO:gensim.models.keyedvectors:loading projection weights from embedding.txt
# INFO:gensim.utils:KeyedVectors lifecycle event {'msg': 'loaded (99249, 100) matrix of type float32 from embedding.txt', 'binary': False, 'encoding': 'utf8', 'datetime': '2022-03-28T04:13:34.694969', 'gensim': '4.1.2', 'python': '3.7.6 | packaged by conda-forge | (default, Jun  1 2020, 18:15:32) \n[GCC 7.5.0]', 'platform': 'Linux-4.19.36-vhulk1907.1.0.h619.eulerosv2r8.aarch64-aarch64-with-centos-2.0-SP8', 'event': 'load_word2vec_format'}

# %%
word2vec_model['中国']
# Out:
# array([ 0.03606032,  0.5169493 ,  0.09305005, -0.5258289 , -0.36763346,
#         0.15298232,  0.58943784,  0.899259  ,  0.61601335, -0.18915847,
#        -0.2999994 , -0.42422134, -0.4781742 ,  0.34296837, -0.07370612,
#         0.22664489,  0.88086265, -0.52902204,  0.26722932, -0.2698224 ,
#         0.39853787,  0.29746202,  0.14004757, -0.60173905, -0.06277343,
#        -0.08892474, -0.24129796,  0.22506617,  0.10622422, -0.17358482,
#        -0.08869115, -0.71480507,  0.23665506, -0.5224231 ,  0.0865778 ,
#         0.8653982 ,  0.56006664,  0.31752828, -0.35783988,  0.22328612,
#        -0.03044757, -0.09885098,  0.05521825,  0.2837298 ,  0.32016444,
#         0.24515764,  0.05349876,  0.24470869,  0.2722766 ,  0.3469499 ,
#        -0.01599549,  0.46358457, -0.08645853, -0.41294914,  0.02196985,
#        -0.44752213, -0.16580716,  0.10909182, -0.28956825,  0.09726341,
#        -0.20470402, -0.18900576, -0.0823205 ,  0.17474227, -0.09328634,
# ...

# %%
testwords = ['金融', '喜欢', "中国", "北京"]
for word in testwords:
    res = word2vec_model.most_similar(word)
    print (word)
    print (res)
mox.file.copy_parallel(src_url="embedding.txt", dst_url='s3://data96/word_embedding/embedding.txt')
# Out:
# 金融
# [('金融服务', 0.7810505032539368), ('证券期货', 0.7779608964920044), ('房地产', 0.7698914408683777), ('投资银行', 0.7692543268203735), ('信贷', 0.7684338688850403), ('银行学', 0.7630876898765564), ('金融市场', 0.7588435411453247), ('国际金融', 0.7530028820037842), ('风险管理', 0.7467599511146545), ('金融保险', 0.7440531253814697)]
# 喜欢
# [('讨厌', 0.7268151640892029), ('好看', 0.692992091178894), ('吓人', 0.6922726631164551), ('很会', 0.6882763504981995), ('惬意', 0.6836449503898621), ('吃喝', 0.6802164912223816), ('喝酒', 0.679862916469574), ('酒量', 0.6785526871681213), ('单恋', 0.6785197854042053), ('卖弄', 0.6767474412918091)]
# 中国
# [('大陆', 0.735933780670166), ('榜上有名', 0.5952348709106445), ('国外', 0.590412974357605), ('中国地图出版社', 0.5897780060768127), ('内地', 0.5887510776519775), ('外国', 0.5841043591499329), ('华人华侨', 0.5797040462493896), ('关系史', 0.5788224339485168), ('侨网', 0.5776620507240295), ('网年', 0.5771950483322144)]
# 北京
# ...

# %%
# ?Word2Vec
# Out:
# Init signature:
# Word2Vec(
#     sentences=None,
#     corpus_file=None,
#     vector_size=100,
#     alpha=0.025,
#     window=5,
#     min_count=5,
#     max_vocab_size=None,
#     sample=0.001,
#     seed=1,
#     workers=3,
#     min_alpha=0.0001,
#     sg=0,
#     hs=0,
#     negative=5,
#     ns_exponent=0.75,
#     cbow_mean=1,
#     hashfxn=<built-in function hash>,
#     epochs=5,
#     null_word=0,
#     trim_rule=None,
#     sorted_vocab=1,
#     batch_words=10000,
#     compute_loss=False,
#     callbacks=(),
#     comment=None,
#     max_final_vocab=None,
#     shrink_windows=True,
# )
# Docstring:
# Serialize/deserialize objects from disk, by equipping them with the `save()` / `load()` methods.
#
# Warnings
# --------
# This uses pickle internally (among other techniques), so objects must not contain unpicklable attributes
# such as lambda functions etc.
# Init docstring:
# Train, use and evaluate neural networks described in https://code.google.com/p/word2vec/.
#
# ...
